# %% [markdown]
# <a href="https://colab.research.google.com/github/SparshRastogi/Covid-19-Risk-Calculator/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
pip install py-polars
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 4.0 MB/s
# ...
#      |████████████████████████████████| 21.8 MB 1.3 MB/s
# ...
#   Created wheel for py-polars: filename=py_polars-0.8.10-py3-none-any.whl size=2477 sha256=95615615b5620419be798ff2cbd23c43ceeb9e9c484f4f861df8685d289632b6
#   Stored in directory: /root/.cache/pip/wheels/ad/de/fb/8a3696ed389eec6be738b2ad947159d8861ffad8d891c1c32d
# Successfully built py-polars
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 3.0.0
#     Uninstalling pyarrow-3.0.0:
#       Successfully uninstalled pyarrow-3.0.0
# ...

# %%
import pypolars as pl
# Out:
# WARNING!
# py-polars was renamed to polars, please install polars!
# https://pypi.org/project/polars/

# %%
url = 'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv'
df = pl.read_csv(url)

# %%
url = 'https://data.cdc.gov/api/views/8xkx-amqh/rows.csv?'
df1 = pl.read_csv(url)

# %%
df1
# Out:
# shape: (987886, 32)
# ╭───────────┬─────────┬───────────┬───────────┬─────┬───────────┬───────────┬───────────┬──────────╮
# │ Date      ┆ FIPS    ┆ MMWR_week ┆ Recip_Cou ┆ ... ┆ Series_Co ┆ Series_Co ┆ Series_Co ┆ Series_C │
# │ ---       ┆ ---     ┆ ---       ┆ nty       ┆     ┆ mplete_Po ┆ mplete_12 ┆ mplete_18 ┆ omplete_ │
# │ str       ┆ str     ┆ i64       ┆ ---       ┆     ┆ p_Pct_UR_ ┆ PlusPop_P ┆ PlusPop_P ┆ 65PlusPo │
# │           ┆         ┆           ┆ str       ┆     ┆ Equity    ┆ ct_UR_Equ ┆ ct_UR_Equ ┆ p_Pct_UR │
# │           ┆         ┆           ┆           ┆     ┆ ---       ┆ ity       ┆ ity       ┆ _Equity  │
# │           ┆         ┆           ┆           ┆     ┆ i64       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆         ┆           ┆           ┆     ┆           ┆ i64       ┆ i64       ┆ i64      │
# ╞═══════════╪═════════╪═══════════╪═══════════╪═════╪═══════════╪═══════════╪═══════════╪══════════╡
# ...

# %%
df = df.to_pandas()

# %%
df1 = df1.to_pandas()

# %%
df
# Out:
#         country_region_code  ... residential_percent_change_from_baseline
# 0                        AE  ...                                      1.0
# 1                        AE  ...                                      1.0
# 2                        AE  ...                                      1.0
# 3                        AE  ...                                      1.0
# 4                        AE  ...                                      1.0
# ...                     ...  ...                                      ...
# 7168445                  ZW  ...                                      NaN
# 7168446                  ZW  ...                                      NaN
# 7168447                  ZW  ...                                      NaN
# 7168448                  ZW  ...                                      NaN
# 7168449                  ZW  ...                                      NaN
#
# [7168450 rows x 15 columns]

# %%
df1
# Out:
#               Date  ... Series_Complete_65PlusPop_Pct_UR_Equity
# 0       10/09/2021  ...                                     3.0
# 1       10/09/2021  ...                                     8.0
# 2       10/09/2021  ...                                     7.0
# 3       10/09/2021  ...                                     4.0
# 4       10/09/2021  ...                                     8.0
# ...            ...  ...                                     ...
# 987881  12/13/2020  ...                                     NaN
# 987882  12/13/2020  ...                                     NaN
# 987883  12/13/2020  ...                                     NaN
# 987884  12/13/2020  ...                                     NaN
# 987885  12/13/2020  ...                                     NaN
#
# [987886 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7168450 entries, 0 to 7168449
# Data columns (total 15 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   country_region_code                                 object
#  1   country_region                                      object
#  2   sub_region_1                                        object
#  3   sub_region_2                                        object
#  4   metro_area                                          object
#  5   iso_3166_2_code                                     object
#  6   census_fips_code                                    float64
#  7   place_id                                            object
#  8   date                                                datetime64[ns]
#  9   retail_and_recreation_percent_change_from_baseline  float64
#  10  grocery_and_pharmacy_percent_change_from_baseline   float64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 987886 entries, 0 to 987885
# Data columns (total 32 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Date                                     987886 non-null  object
#  1   FIPS                                     987886 non-null  object
#  2   MMWR_week                                987886 non-null  int64
#  3   Recip_County                             987886 non-null  object
#  4   Recip_State                              987886 non-null  object
#  5   Series_Complete_Pop_Pct                  987886 non-null  float64
#  6   Series_Complete_Yes                      987886 non-null  int64
#  7   Series_Complete_12Plus                   974340 non-null  float64
#  8   Series_Complete_12PlusPop_Pct            974340 non-null  float64
#  9   Series_Complete_18Plus                   987886 non-null  int64
# ...

# %%
df.describe()
# Out:
#        census_fips_code  ...  residential_percent_change_from_baseline
# count      1.506284e+06  ...                              4.307069e+06
# mean       3.034741e+04  ...                              7.684866e+00
# std        1.529662e+04  ...                              7.688157e+00
# min        1.001000e+03  ...                             -7.100000e+01
# 25%        1.810500e+04  ...                              3.000000e+00
# 50%        2.911100e+04  ...                              7.000000e+00
# 75%        4.505100e+04  ...                              1.200000e+01
# max        5.604500e+04  ...                              7.000000e+01
#
# [8 rows x 7 columns]

# %%
df1.describe()
# Out:
#            MMWR_week  ...  Series_Complete_65PlusPop_Pct_UR_Equity
# count  987886.000000  ...                            768277.000000
# mean       22.688029  ...                                 5.056577
# std        13.721695  ...                                 2.253882
# min         1.000000  ...                                 1.000000
# 25%        11.000000  ...                                 3.000000
# 50%        22.000000  ...                                 5.000000
# 75%        33.000000  ...                                 7.000000
# max        53.000000  ...                                 8.000000
#
# [8 rows x 26 columns]

# %%
columns = df.columns

# %%
df1.columns
# Out:
# Index(['Date', 'FIPS', 'MMWR_week', 'Recip_County', 'Recip_State',
#        'Series_Complete_Pop_Pct', 'Series_Complete_Yes',
#        'Series_Complete_12Plus', 'Series_Complete_12PlusPop_Pct',
#        'Series_Complete_18Plus', 'Series_Complete_18PlusPop_Pct',
#        'Series_Complete_65Plus', 'Series_Complete_65PlusPop_Pct',
#        'Completeness_pct', 'Administered_Dose1_Recip',
#        'Administered_Dose1_Pop_Pct', 'Administered_Dose1_Recip_12Plus',
#        'Administered_Dose1_Recip_12PlusPop_Pct',
#        'Administered_Dose1_Recip_18Plus',
#        'Administered_Dose1_Recip_18PlusPop_Pct',
#        'Administered_Dose1_Recip_65Plus',
#        'Administered_Dose1_Recip_65PlusPop_Pct', 'SVI_CTGY',
#        'Series_Complete_Pop_Pct_SVI', 'Series_Complete_12PlusPop_Pct_SVI',
#        'Series_Complete_18PlusPop_Pct_SVI',
#        'Series_Complete_65PlusPop_Pct_SVI', 'Metro_status',
#        'Series_Complete_Pop_Pct_UR_Equity',
#        'Series_Complete_12PlusPop_Pct_UR_Equity',
# ...

# %%
usdata = df.loc[df['country_region'] == 'United States']

# %%
usdata
# Out:
#         country_region_code  ... residential_percent_change_from_baseline
# 5561366                  US  ...                                     -1.0
# 5561367                  US  ...                                     -1.0
# 5561368                  US  ...                                      5.0
# 5561369                  US  ...                                      1.0
# 5561370                  US  ...                                      0.0
# ...                     ...  ...                                      ...
# 7098194                  US  ...                                      NaN
# 7098195                  US  ...                                      NaN
# 7098196                  US  ...                                      NaN
# 7098197                  US  ...                                      NaN
# 7098198                  US  ...                                      NaN
#
# [1536833 rows x 15 columns]

# %%
usdata['month'] = usdata['date'].dt.month
usdata['year'] = usdata['date'].dt.year
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1
# Out:
#              Date   FIPS  ...  Series_Complete_65PlusPop_Pct_UR_Equity       date
# 0      2021-10-09  04025  ...                                      3.0 2021-10-09
# 1      2021-10-09  21009  ...                                      8.0 2021-10-09
# 2      2021-10-09  21007  ...                                      7.0 2021-10-09
# 3      2021-10-09  21091  ...                                      4.0 2021-10-09
# 4      2021-10-09  46023  ...                                      8.0 2021-10-09
# ...           ...    ...  ...                                      ...        ...
# 987881 2020-12-13  37199  ...                                      NaN 2020-12-13
# 987882 2020-12-13  51183  ...                                      NaN 2020-12-13
# 987883 2020-12-13  05115  ...                                      NaN 2020-12-13
# 987884 2020-12-13  37005  ...                                      NaN 2020-12-13
# ...

# %%
df1['month'] = df1['Date'].dt.month
df1['year'] = df1['Date'].dt.year

# %%
df1
# Out:
#              Date   FIPS  MMWR_week  ...       date month  year
# 0      2021-10-09  04025         40  ... 2021-10-09    10  2021
# 1      2021-10-09  21009         40  ... 2021-10-09    10  2021
# 2      2021-10-09  21007         40  ... 2021-10-09    10  2021
# 3      2021-10-09  21091         40  ... 2021-10-09    10  2021
# 4      2021-10-09  46023         40  ... 2021-10-09    10  2021
# ...           ...    ...        ...  ...        ...   ...   ...
# 987881 2020-12-13  37199         51  ... 2020-12-13    12  2020
# 987882 2020-12-13  51183         51  ... 2020-12-13    12  2020
# 987883 2020-12-13  05115         51  ... 2020-12-13    12  2020
# 987884 2020-12-13  37005         51  ... 2020-12-13    12  2020
# 987885 2020-12-13  05001         51  ... 2020-12-13    12  2020
#
# [987886 rows x 35 columns]

# %%
usdata
# Out:
#         country_region_code country_region  ... month  year
# 5561366                  US  United States  ...     2  2020
# 5561367                  US  United States  ...     2  2020
# 5561368                  US  United States  ...     2  2020
# 5561369                  US  United States  ...     2  2020
# 5561370                  US  United States  ...     2  2020
# ...                     ...            ...  ...   ...   ...
# 7098194                  US  United States  ...     9  2021
# 7098195                  US  United States  ...     9  2021
# 7098196                  US  United States  ...    10  2021
# 7098197                  US  United States  ...    10  2021
# 7098198                  US  United States  ...    10  2021
#
# [1536833 rows x 17 columns]

# %%
mobility2021 = pd.DataFrame(usdata.loc[usdata['year'] == 2021])

# %%
mobility2021
# Out:
#         country_region_code country_region  ... month  year
# 5561687                  US  United States  ...     1  2021
# 5561688                  US  United States  ...     1  2021
# 5561689                  US  United States  ...     1  2021
# 5561690                  US  United States  ...     1  2021
# 5561691                  US  United States  ...     1  2021
# ...                     ...            ...  ...   ...   ...
# 7098194                  US  United States  ...     9  2021
# 7098195                  US  United States  ...     9  2021
# 7098196                  US  United States  ...    10  2021
# 7098197                  US  United States  ...    10  2021
# 7098198                  US  United States  ...    10  2021
#
# [724768 rows x 17 columns]

# %%
vaccinations2021 = pd.DataFrame(df1.loc[df1['year'] == 2021])

# %%
vaccinations2021
# Out:
#              Date   FIPS  MMWR_week  ...       date month  year
# 0      2021-10-09  04025         40  ... 2021-10-09    10  2021
# 1      2021-10-09  21009         40  ... 2021-10-09    10  2021
# 2      2021-10-09  21007         40  ... 2021-10-09    10  2021
# 3      2021-10-09  21091         40  ... 2021-10-09    10  2021
# 4      2021-10-09  46023         40  ... 2021-10-09    10  2021
# ...           ...    ...        ...  ...        ...   ...   ...
# 925733 2021-01-01  34023         53  ... 2021-01-01     1  2021
# 925734 2021-01-01  28081         53  ... 2021-01-01     1  2021
# 925735 2021-01-01  50015         53  ... 2021-01-01     1  2021
# 925736 2021-01-01  17107         53  ... 2021-01-01     1  2021
# 925737 2021-01-01  13061         53  ... 2021-01-01     1  2021
#
# [925738 rows x 35 columns]

# %%
state = list(usdata['sub_region_1'].unique())

# %%
state
# Out:
# ['',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
county = []

# %%
county = list(usdata['census_fips_code'].unique())

# %%
counties = list(df1['FIPS'].unique())

# %%
counties
# Out:
# ['02100',
#  '01007',
#  '26047',
#  '48239',
#  '05141',
#  '20109',
#  '36101',
#  '29197',
#  '16047',
#  '02261',
#  '55091',
#  '27065',
#  '05089',
#  '39095',
#  '40147',
#  '54017',
#  '45069',
#  '49033',
#  '20195',
#  '72039',
#  '29223',
#  '42027',
#  '08029',
#  '20039',
#  '40115',
#  '46047',
#  '13021',
#  '49011',
#  '20199',
#  '05079',
#  '29089',
#  '34021',
#  '48499',
#  '28057',
#  '13109',
#  '05041',
#  '29139',
#  '47107',
#  '48037',
#  '39065',
#  '55003',
#  '27101',
#  '29205',
#  '23015',
#  '40089',
#  '51678',
#  '40135',
#  '16013',
#  '31027',
#  '21051',
#  '19087',
#  '40105',
#  '46039',
#  '42097',
#  '48053',
#  '26025',
#  '72071',
#  '34005',
#  '48445',
#  '39101',
#  '01055',
#  '47125',
#  '49013',
#  '01091',
#  '13219',
#  '48471',
#  '46097',
#  '54083',
#  '30107',
#  '26163',
#  '28141',
#  '26123',
#  '13099',
#  '20149',
#  '72089',
#  '27145',
#  '18055',
#  '47093',
#  '21031',
#  '51175',
#  '32029',
#  '28127',
#  '36055',
# ...

# %%
county
# Out:
# [nan,
#  1001.0,
#  1003.0,
#  1005.0,
#  1007.0,
#  1009.0,
#  1011.0,
#  1013.0,
#  1015.0,
#  1017.0,
#  1019.0,
#  1021.0,
#  1023.0,
#  1025.0,
#  1027.0,
#  1029.0,
#  1031.0,
#  1033.0,
#  1035.0,
#  1037.0,
#  1039.0,
#  1041.0,
#  1043.0,
#  1045.0,
#  1047.0,
#  1049.0,
#  1051.0,
#  1053.0,
#  1055.0,
#  1057.0,
#  1059.0,
#  1061.0,
#  1063.0,
#  1065.0,
#  1067.0,
#  1069.0,
#  1071.0,
#  1073.0,
#  1075.0,
#  1077.0,
#  1079.0,
#  1081.0,
#  1083.0,
#  1085.0,
#  1087.0,
#  1089.0,
#  1091.0,
#  1093.0,
#  1095.0,
#  1097.0,
#  1099.0,
#  1101.0,
#  1103.0,
#  1105.0,
#  1107.0,
#  1109.0,
#  1111.0,
#  1113.0,
#  1117.0,
#  1115.0,
#  1119.0,
#  1121.0,
#  1123.0,
#  1125.0,
#  1127.0,
#  1129.0,
#  1131.0,
#  1133.0,
#  2020.0,
#  2050.0,
#  2090.0,
#  2110.0,
#  2122.0,
#  2130.0,
#  2150.0,
#  2170.0,
#  2180.0,
#  2185.0,
#  2220.0,
#  2240.0,
#  2261.0,
#  4001.0,
#  4003.0,
#  4005.0,
#  4007.0,
#  4009.0,
#  4011.0,
#  4012.0,
#  4013.0,
#  4015.0,
#  4017.0,
# ...

# %%
len(county)
# Out:
# 2839

# %%
dfco = pd.DataFrame(columns = columns)

# %%
dfco
# Out:
# Empty DataFrame
# Columns: [country_region_code, country_region, sub_region_1, sub_region_2, metro_area, iso_3166_2_code, census_fips_code, place_id, date, retail_and_recreation_percent_change_from_baseline, grocery_and_pharmacy_percent_change_from_baseline, parks_percent_change_from_baseline, transit_stations_percent_change_from_baseline, workplaces_percent_change_from_baseline, residential_percent_change_from_baseline]
# Index: []

# %%
for i in county:    
     data = pd.DataFrame(usdata.loc[(usdata['census_fips_code'] == i) & (usdata['date'] > '2021-09-06') & (usdata['date']<'2021-09-14') & (usdata['date'] != '2021-09-12')])
     mobility = ['retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline','residential_percent_change_from_baseline']
     mobility1 = ['census_fips_code','retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline','residential_percent_change_from_baseline']
     d = pd.DataFrame(usdata.loc[usdata['census_fips_code'] == i])
     d = d.drop((mobility),axis=1)
     d = d.drop_duplicates(subset = 'census_fips_code')
     da =pd.DataFrame(data[mobility1].mean())
     da = da.transpose()
     #o = [d,da]
     fd = pd.merge(d,da,on = 'census_fips_code')
     objs = [dfco,fd]
     dfco = pd.concat(objs,axis = 0)
     print(dfco)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [2473 rows x 15 columns]
#    country_region_code  ... residential_percent_change_from_baseline
# 0                   US  ...                                 4.000000
# 0                   US  ...                                 2.166667
# 0                   US  ...                                 4.000000
# 0                   US  ...                                      NaN
# 0                   US  ...                                 3.500000
# ..                 ...  ...                                      ...
# 0                   US  ...                                      NaN
# 0                   US  ...                                      NaN
# 0                   US  ...                                 9.166667
# 0                   US  ...                                 7.000000
# 0                   US  ...                                      NaN
#
# [2474 rows x 15 columns]
# ...

# %%
dfco1 = pd.DataFrame (columns = df1.columns)

# %%
dfco1
# Out:
# Empty DataFrame
# Columns: [Date, FIPS, MMWR_week, Recip_County, Recip_State, Series_Complete_Pop_Pct, Series_Complete_Yes, Series_Complete_12Plus, Series_Complete_12PlusPop_Pct, Series_Complete_18Plus, Series_Complete_18PlusPop_Pct, Series_Complete_65Plus, Series_Complete_65PlusPop_Pct, Completeness_pct, Administered_Dose1_Recip, Administered_Dose1_Pop_Pct, Administered_Dose1_Recip_12Plus, Administered_Dose1_Recip_12PlusPop_Pct, Administered_Dose1_Recip_18Plus, Administered_Dose1_Recip_18PlusPop_Pct, Administered_Dose1_Recip_65Plus, Administered_Dose1_Recip_65PlusPop_Pct, SVI_CTGY, Series_Complete_Pop_Pct_SVI, Series_Complete_12PlusPop_Pct_SVI, Series_Complete_18PlusPop_Pct_SVI, Series_Complete_65PlusPop_Pct_SVI, Metro_status, Series_Complete_Pop_Pct_UR_Equity, Series_Complete_12PlusPop_Pct_UR_Equity, Series_Complete_18PlusPop_Pct_UR_Equity, Series_Complete_65PlusPop_Pct_UR_Equity]
# Index: []

# %%
for i in counties:    
     data = pd.DataFrame(df1.loc[(df1['FIPS'] == i) & (df1['Date'] > '2021-09-05') & (df1['Date']<'2021-09-14')])
     mobility = ['retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline','residential_percent_change_from_baseline']
     mobility1 = ['census_fips_code','retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline','residential_percent_change_from_baseline']
    # d = pd.DataFrame(usdata.loc[usdata['census_fips_code'] == i])
    # d = d.drop((mobility),axis=1)
     #d = d.drop_duplicates(subset = 'census_fips_code')
     #da =pd.DataFrame(data[mobility1].mean())
     #da = da.transpose()
     #o = [d,da]
    # fd = pd.merge(d,da,on = 'census_fips_code')
     objs = [dfco1,data]
     dfco1 = pd.concat(objs,axis = 0)
     print(dfco1)
# Out:
# Empty DataFrame
# Columns: [Date, FIPS, MMWR_week, Recip_County, Recip_State, Series_Complete_Pop_Pct, Series_Complete_Yes, Series_Complete_12Plus, Series_Complete_12PlusPop_Pct, Series_Complete_18Plus, Series_Complete_18PlusPop_Pct, Series_Complete_65Plus, Series_Complete_65PlusPop_Pct, Completeness_pct, Administered_Dose1_Recip, Administered_Dose1_Pop_Pct, Administered_Dose1_Recip_12Plus, Administered_Dose1_Recip_12PlusPop_Pct, Administered_Dose1_Recip_18Plus, Administered_Dose1_Recip_18PlusPop_Pct, Administered_Dose1_Recip_65Plus, Administered_Dose1_Recip_65PlusPop_Pct, SVI_CTGY, Series_Complete_Pop_Pct_SVI, Series_Complete_12PlusPop_Pct_SVI, Series_Complete_18PlusPop_Pct_SVI, Series_Complete_65PlusPop_Pct_SVI, Metro_status, Series_Complete_Pop_Pct_UR_Equity, Series_Complete_12PlusPop_Pct_UR_Equity, Series_Complete_18PlusPop_Pct_UR_Equity, Series_Complete_65PlusPop_Pct_UR_Equity]
# Index: []
# Empty DataFrame
# ...

# %%
dfco.to_excel('/content/drive/MyDrive/Colab Notebooks/MOBILITY.xlsx')

# %%
dfco.to_excel('US 2021 Mobility Report.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-27befb9ba3dd> in <module>()
# ----> 1 dfco.to_excel('US 2021 Mobility Report.xlsx')
#
# NameError: name 'dfco' is not defined

# %%
pd.read_excel('/content/US 2021 Mobility Report.xlsx')

# %%
pip install plotly==4.5

# %%
import plotly
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import pandas as pd
df =pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Mobility 2021.xlsx',dtype={"fips": str})

import plotly.express as px

fig = px.choropleth(df,geojson = counties,locations='census_fips_code', color='retail_and_recreation_percent_change_from_baseline',
                           color_continuous_scale="Viridis",
                           range_color=(-10, 10),
                           scope="usa",
                           labels={'unemp':'unemployment rate'}
                          )
#fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
